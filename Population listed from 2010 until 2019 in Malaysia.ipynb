# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
population_census = pd.read_excel('C:/Users/hakim/Downloads/Population_by_age_group_sex_and_ethnic_group_2010-2019e_Malaysia.xlsx')
population_census
# Out:
#          Sex Age Group   Year        Citizen category      Ethnic  \
# 0       Male       0-4   2010      Malaysian citizens  Bumiputera
# 1       Male       0-4   2010      Malaysian citizens     Chinese
# 2       Male       0-4   2010      Malaysian citizens     Indians
# 3       Male       0-4   2010      Malaysian citizens      Others
# 4       Male       0-4   2010  Non-Malaysian citizens         NaN
# 5       Male       5-9   2010      Malaysian citizens  Bumiputera
# 6       Male       5-9   2010      Malaysian citizens     Chinese
# 7       Male       5-9   2010      Malaysian citizens     Indians
# 8       Male       5-9   2010      Malaysian citizens      Others
# 9       Male       5-9   2010  Non-Malaysian citizens         NaN
# 10      Male     10-14   2010      Malaysian citizens  Bumiputera
# 11      Male     10-14   2010      Malaysian citizens     Chinese
# 12      Male     10-14   2010      Malaysian citizens     Indians
# ...

# %%
population_census.isna().sum()
# Out:
# Sex                    0
# Age Group              0
# Year                   0
# Citizen category       0
# Ethnic               340
# Population ("000)      0
# dtype: int64

# %%
population_census.dtypes
# Out:
# Sex                   object
# Age Group             object
# Year                  object
# Citizen category      object
# Ethnic                object
# Population ("000)    float64
# dtype: object

# %%
population_census.hist(bins=60)
# Out:
# array([[<AxesSubplot:title={'center':'Population ("000)'}>]], dtype=object)

# %%
population_census[['Citizen category','Population ("000)']].plot(kind='scatter', x='Citizen category', y='Population ("000)')
# Out:
# <AxesSubplot:xlabel='Citizen category', ylabel='Population ("000)'>

# %%
population_census[['Sex','Population ("000)']].plot(kind='scatter', x='Sex', y='Population ("000)', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Population ("000)'>

# %%
population_census.fillna ('Not Applicable')
# Out:
#          Sex Age Group   Year        Citizen category          Ethnic  \
# 0       Male       0-4   2010      Malaysian citizens      Bumiputera
# 1       Male       0-4   2010      Malaysian citizens         Chinese
# 2       Male       0-4   2010      Malaysian citizens         Indians
# 3       Male       0-4   2010      Malaysian citizens          Others
# 4       Male       0-4   2010  Non-Malaysian citizens  Not Applicable
# 5       Male       5-9   2010      Malaysian citizens      Bumiputera
# 6       Male       5-9   2010      Malaysian citizens         Chinese
# 7       Male       5-9   2010      Malaysian citizens         Indians
# 8       Male       5-9   2010      Malaysian citizens          Others
# 9       Male       5-9   2010  Non-Malaysian citizens  Not Applicable
# 10      Male     10-14   2010      Malaysian citizens      Bumiputera
# 11      Male     10-14   2010      Malaysian citizens         Chinese
# ...
